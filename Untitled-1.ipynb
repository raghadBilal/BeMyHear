# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
from mediapipe.python.solutions.face_mesh_connections import FACEMESH_CONTOURS
import tensorflow
from mediapipe.python.solutions.face_mesh_connections import FACEMESH_TESSELATION
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
    #  Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
  
            # Read feed
            ret, frame = cap.read()

            # Make detections
            image, results =mediapipe_detection(frame, holistic)
            print(results)
        
            # Draw landmarks
            draw_styled_landmarks(image, results)

            # Show to screen
            cv2.imshow('OpenCV Feed', image)
            array=[frame,results]

            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                 break
        
        cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\user\Desktop\Be My Hear1\Untitled-1.ipynb Cell 6' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000005?line=2'>3</a> with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000005?line=3'>4</a>         while cap.isOpened():
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000005?line=4'>5</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000005?line=5'>6</a>             # Read feed
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000005?line=6'>7</a>             ret, frame = cap.read()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000005?line=8'>9</a>             # Make detections
#      <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000005?line=9'>10</a>             image, results =mediapipe_detection(frame, holistic)
#
# KeyboardInterrupt:

# %%
draw_landmarks(frame, results)

# %%
def Extract_Keypoint_Values():
    pose = []
    for res in results.pose_landmarks.landmark:
        test = np.array([res.x, res.y, res.z, res.visibility])
        pose.append(test)
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)    
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() 
if results.face_landmarks :
         True
else:
         np.zeros(1404)

# %%
Extract_Keypoint_Values()

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.51751715,  0.33649698, -1.42151761, ...,  0.        ,
#         0.        ,  0.        ])

# %%
def set_up():
    # Path for exported data, numpy arrays
    DATA_PATH = os.path.join('MP_Data') 

    # Actions that we try to detect
    actions = np.array(['welcome', 'in', 'MyApplication'])

    # Thirty videos worth of data
    no_sequences = 30

    # Videos are going to be 30 frames in length
    sequence_length = 30

    # Folder start
    start_folder = 30
    array=[no_sequences,actions,sequence_length,start_folder,DATA_PATH]


    for action in actions:
     for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

    return array

# %%
x = r'C:\Users\user\Desktop\Be My Hear1' 
if not os.path.exists(x):
    os.makedirs(x)

# %%
x=set_up()
no_sequences=x[0]
actions=x[1]
sequence_length=x[2]
start_folder=x[3]
DATA_PATH=x[4]

# %%
def collect_keypoint():
    cap = cv2.VideoCapture(0)
    # Set mediapipe model 
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
          for action in actions:
        # Loop through sequences aka videos
           for sequence in range(no_sequences):
            # Loop through video length aka sequence length
             for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
#collect_keypoint()

# %%
def Create_Labels():
    label_map = {label:num for num, label in enumerate(actions)}
    sequences, labels = [], []
    for action in actions:
          for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
                window = []
                for frame_num in range(sequence_length):
                    res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
                    window.append(res)
                sequences.append(window)
                labels.append(label_map[action])
    array=[label_map,sequences, labels,res,window]
    return array

y=Create_Labels()
label_map=y[0]
sequences=y[1]
labels=y[2]
res=y[3]
window=y[4]

# %%
def Preprocess_Data(sequences,labels) :
    np.array(sequences).shape
    np.array(labels).shape
    X = np.array(sequences)
    y = to_categorical(labels).astype(int)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
    array=[X_train, X_test, y_train, y_test]
    return array

z=Preprocess_Data(sequences,labels)
X_train= z[0]
X_test=z[1]
y_train=z[2]
y_test=z[3]

# %%
def Train_LSTM():
    log_dir = os.path.join('Logs')
    tb_callback = TensorBoard(log_dir=log_dir)
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
    model.add(LSTM(128, return_sequences=True, activation='relu'))
    model.add(LSTM(64, return_sequences=False, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(actions.shape[0], activation='softmax'))  
    return model

# %%
model=Train_LSTM()
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 5s 229ms/step - loss: 1.8143 - categorical_accuracy: 0.3412
# Epoch 2/2000
# 3/3 [==============================] - 0s 194ms/step - loss: 12.1484 - categorical_accuracy: 0.3647
# Epoch 3/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 1.6573 - categorical_accuracy: 0.2706
# Epoch 4/2000
# 3/3 [==============================] - 0s 171ms/step - loss: 8.0733 - categorical_accuracy: 0.3647
# Epoch 5/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 12.5584 - categorical_accuracy: 0.3647
# Epoch 6/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 34.1829 - categorical_accuracy: 0.2941
# Epoch 7/2000
# 3/3 [==============================] - ETA: 0s - loss: 84.5194 - categorical_accuracy: 0.3647
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\user\Desktop\Be My Hear1\Untitled-1.ipynb Cell 22' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000021?line=2'>3</a> tb_callback = TensorBoard(log_dir=log_dir)
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000021?line=3'>4</a> model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Be%20My%20Hear1/Untitled-1.ipynb#ch0000021?line=4'>5</a> model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# File c:\Users\user\Desktop\python\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\user\Desktop\python\lib\site-packages\keras\engine\training.py:1435, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/engine/training.py?line=1431'>1432</a>   val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/engine/training.py?line=1432'>1433</a>   epoch_logs.update(val_logs)
# -> <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/engine/training.py?line=1434'>1435</a> callbacks.on_epoch_end(epoch, epoch_logs)
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/engine/training.py?line=1435'>1436</a> training_logs = epoch_logs
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/engine/training.py?line=1436'>1437</a> if self.stop_training:
#
# File c:\Users\user\Desktop\python\lib\site-packages\keras\callbacks.py:416, in CallbackList.on_epoch_end(self, epoch, logs)
#     <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=413'>414</a> logs = self._process_logs(logs)
#     <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=414'>415</a> for callback in self.callbacks:
# --> <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=415'>416</a>   callback.on_epoch_end(epoch, logs)
#
# File c:\Users\user\Desktop\python\lib\site-packages\keras\callbacks.py:2503, in TensorBoard.on_epoch_end(self, epoch, logs)
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2500'>2501</a> def on_epoch_end(self, epoch, logs=None):
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2501'>2502</a>   """Runs metrics and histogram summaries at epoch end."""
# -> <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2502'>2503</a>   self._log_epoch_metrics(epoch, logs)
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2504'>2505</a>   if self.histogram_freq and epoch % self.histogram_freq == 0:
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2505'>2506</a>     self._log_weights(epoch)
#
# File c:\Users\user\Desktop\python\lib\site-packages\keras\callbacks.py:2558, in TensorBoard._log_epoch_metrics(self, epoch, logs)
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2555'>2556</a> with tf.summary.record_if(True):
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2556'>2557</a>   if train_logs:
# -> <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2557'>2558</a>     with self._train_writer.as_default():
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2558'>2559</a>       for name, value in train_logs.items():
#    <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/keras/callbacks.py?line=2559'>2560</a>         tf.summary.scalar('epoch_' + name, value, step=epoch)
#
# File c:\Users\user\Desktop\python\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:93, in _SummaryContextManager.__exit__(self, *exc)
#      <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/summary_ops_v2.py?line=89'>90</a> def __exit__(self, *exc):
#      <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/summary_ops_v2.py?line=90'>91</a>   # Flushes the summary writer in eager mode or in graph functions, but
#      <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/summary_ops_v2.py?line=91'>92</a>   # not in legacy graph mode (you're on your own there).
# ---> <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/summary_ops_v2.py?line=92'>93</a>   _summary_state.writer.flush()
#      <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/summary_ops_v2.py?line=93'>94</a>   _summary_state.writer = self._old_writer
#      <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/summary_ops_v2.py?line=94'>95</a>   if self._step is not None:
#
# File c:\Users\user\Desktop\python\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:345, in _ResourceSummaryWriter.flush(self)
#     <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/summary_ops_v2.py?line=342'>343</a>   return
#     <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/summary_ops_v2.py?line=343'>344</a> with ops.device("cpu:0"):
# --> <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/summary_ops_v2.py?line=344'>345</a>   return gen_summary_ops.flush_summary_writer(self._resource)
#
# File c:\Users\user\Desktop\python\lib\site-packages\tensorflow\python\ops\gen_summary_ops.py:193, in flush_summary_writer(writer, name)
#     <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/gen_summary_ops.py?line=190'>191</a> if tld.is_eager:
#     <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/gen_summary_ops.py?line=191'>192</a>   try:
# --> <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/gen_summary_ops.py?line=192'>193</a>     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/gen_summary_ops.py?line=193'>194</a>       _ctx, "FlushSummaryWriter", name, writer)
#     <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/gen_summary_ops.py?line=194'>195</a>     return _result
#     <a href='file:///c%3A/Users/user/Desktop/python/lib/site-packages/tensorflow/python/ops/gen_summary_ops.py?line=195'>196</a>   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
def Make_Predictions(model,X_test):
    res = model.predict(X_test)
    model.save('action.h5')
    model.load_weights('action.h5')
    return res

res=Make_Predictions(model,X_test)

# %%
def Evaluation(model,X_test):
    yhat = model.predict(X_test)
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    multilabel_confusion_matrix(ytrue, yhat)
    accuracy_score(ytrue, yhat)
    array=[ytrue, yhat]
    return array


d=Evaluation(model,X_test)
ytrue=d[0]
yhat=d[1]

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# in
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# MyApplication
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# welcome
